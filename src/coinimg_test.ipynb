# %%
import cv2
# from config import config
from skimage import io
import numpy as np
import os
import time
import sys
import coinimg as ci
import PySimpleGUI as sg
import os
import matplotlib.pyplot as plt

# %%
# image = io.imread(f'../crapPics/test1.png')
image = io.imread('C:/Muenzzaehler/crapPics/14%V18%C/1Euro42.png')
regions, binaryImage, labeledImage, hsvImage = ci.regions(image, minRegionSize=1000, threshold=10, return_steps=True)

# %%
print(len(regions))
for region in regions:
    print(region)
# Out:
# 7
# (2765, 124.95443037974684)
# (3972, 76.75923128566633)
# (4832, 74.0725027593819)
# (3635, 122.16286107290234)
# (3226, 132.45980574498864)
# (3636, 121.79134580124679)
# (4866, 94.99965748732703)

# %%
plt.figure(figsize=(12,12))
plt.subplot(1,4,(1))
plt.imshow(image)
plt.title('image')
plt.subplot(1,4,(2))
plt.imshow(binaryImage,cmap="gray")
plt.title('binaryImage')
plt.subplot(1,4,(3))
plt.imshow(labeledImage,cmap="gray")
plt.title('labeledImage')
plt.subplot(1,4,(4))
plt.imshow(hsvImage,cmap="gray")
plt.title('hsvImage');
