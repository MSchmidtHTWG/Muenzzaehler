# %%
import cv2
# from config import config
from skimage import io
import numpy as np
import os
import time
import sys
import coinimg as ci
# import PySimpleGUI as sg
import os
import matplotlib.pyplot as plt

# %%
# image = io.imread(f'../crapPics/test1.png')
# image = io.imread(f'../crapPics/14%V18%C/1Euro42.png')
image = io.imread(f'../reference/2Euro0.png')
regions, binaryImage, labeledImage, hsvImage = ci.regions(image, minRegionSize=500, threshold=20, return_steps=True)

# %%
print(len(regions))
for region in regions:
    print(region)
# Out:
# 3
# (1450, 56.888275862068966)
# (81845, 64.38125725456656)
# (662, 65.38368580060423)

# %%
plt.figure(figsize=(12,12))
plt.subplot(1,4,(1))
plt.imshow(image)
plt.title('image')
plt.subplot(1,4,(2))
plt.imshow(binaryImage,cmap="gray")
plt.title('binaryImage')
plt.subplot(1,4,(3))
plt.imshow(labeledImage,cmap="gray")
plt.title('labeledImage')
plt.subplot(1,4,(4))
plt.imshow(hsvImage,cmap="gray")
plt.title('hsvImage');
