# %%
import cv2
# from config import config
from skimage import io
import numpy as np
import os
import time
import sys
import coinimg as ci
# import PySimpleGUI as sg
import os
import matplotlib.pyplot as plt
import colorsys

# %%
image = io.imread(f'../testimages/test12.png')

# %%
#ci.saveDict()
cd = ci.loadDict()
for c in cd:
    print(c + str(cd.get(c)))
# Out:
# 2Euro(10975, 12222, 34.41738786494808)
# 1Euro(8843, 10389, 34.1437044137298)
# 50Cent(9613, 11108, 29.754680372634958)
# 20Cent(8014, 9491, 28.89423448669848)
# 10Cent(6228, 7327, 29.486032003249797)
# 5Cent(7081, 8454, 16.24357741206176)
# 2Cent(5549, 6824, 17.01866742600001)
# 1Cent(4096, 5252, 16.89341883630191)

# %%
image = io.imread(f'../testimages/test12.png')
regions, binaryImage, labeledImage = ci.regions(image, minRegionSize=500, threshold=25, return_steps=True)
predictions, groupImage = ci.predict(regions, np.shape(image))
print(predictions)
print(ci.count(predictions))
# Out:
# ['1Euro', '20Cent', '2Euro', '50Cent', '10Cent']
# 3.8€

# %%
print(len(regions))
for region in regions:
    print(region)
# Out:
# 5
# (9328, 32.10141509433962, (array([308, 308, 308, ..., 415, 416, 417], dtype=int64), array([355, 358, 360, ..., 371, 354, 354], dtype=int64)))
# (9118, 27.58291291949989, (array([146, 147, 148, ..., 284, 285, 285], dtype=int64), array([491, 491, 488, ..., 477, 477, 478], dtype=int64)))
# (11854, 33.26885439514088, (array([132, 133, 133, ..., 258, 258, 259], dtype=int64), array([142, 121, 142, ..., 138, 147, 147], dtype=int64)))
# (10868, 28.476904674273094, (array([ 92,  92,  92, ..., 209, 209, 210], dtype=int64), array([351, 354, 355, ..., 362, 365, 349], dtype=int64)))
# (7404, 29.83698001080497, (array([ 33,  34,  34, ..., 131, 132, 132], dtype=int64), array([452, 436, 451, ..., 469, 435, 436], dtype=int64)))

# %%
plt.figure(figsize=(12,12))
plt.subplot(1,4,(1))
plt.imshow(image)
plt.title('image')
plt.subplot(1,4,(2))
plt.imshow(binaryImage,cmap="gray")
plt.title('binaryImage')
plt.subplot(1,4,(3))
plt.imshow(labeledImage,cmap="gray")
plt.title('labeledImage')
plt.subplot(1,4,(4))
plt.imshow(groupImage)
plt.title('groupImage');

# %%
image = io.imread(f'../testimages/test0.png')
regions, binaryImage, labeledImage = ci.regions(image, minRegionSize=500, threshold=30, return_steps=True)
predictions, groupImage = ci.predict(regions, np.shape(image))
print(predictions)
print(ci.count(predictions))
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-9-b25b9c5ed698> in <module>
#       1 image = io.imread(f'../testimages/test0.png')
# ----> 2 regions, binaryImage, labeledImage = ci.regions(image, minRegionSize=500, threshold=30, return_steps=True)
#       3 predictions, groupImage = ci.predict(regions, np.shape(image))
#       4 print(predictions)
#       5 print(ci.count(predictions))
#
# c:\Muenzzaehler\src\coinimg.py in regions(image, minRegionSize, threshold, return_steps)
#     174 def regions(image, minRegionSize=0, threshold=0, return_steps=False):
#     175     binaryImage = rgbToBinary(image, threshold)
# --> 176     labeledImage = sequentialLabeling(binaryImage)
#     177     hsvImage = cv2.cvtColor(image, cv2.COLOR_RGB2HSV)
#     178
#
# c:\Muenzzaehler\src\coinimg.py in sequentialLabeling(binaryImage, n)
#     280             if img[v][u] > 1:
#     281                 for lsets in r:
# --> 282                     if lsets.issuperset({img[v][u]}):
#     283                         img[v][u] = min(lsets)
#     284     return invert(img)
#
# KeyboardInterrupt:

# %%
print(len(regions))
for region in regions:
    print(region)
# Out:
# 8
# (6727, 27.266983796640403, (array([310, 311, 311, ..., 401, 402, 402], dtype=int64), array([306, 293, 294, ..., 311, 300, 306], dtype=int64)))
# (9088, 30.609044894366196, (array([277, 277, 277, ..., 384, 384, 384], dtype=int64), array([166, 167, 168, ..., 178, 179, 180], dtype=int64)))
# (7640, 16.097905759162305, (array([243, 244, 245, ..., 347, 348, 349], dtype=int64), array([552, 552, 552, ..., 548, 548, 548], dtype=int64)))
# (8786, 26.72376508081038, (array([216, 216, 216, ..., 321, 321, 321], dtype=int64), array([386, 387, 388, ..., 401, 402, 403], dtype=int64)))
# (11767, 32.051584940936515, (array([118, 119, 120, ..., 244, 244, 245], dtype=int64), array([151, 151, 147, ..., 156, 157, 151], dtype=int64)))
# (10749, 28.471671783421712, (array([ 62,  62,  62, ..., 179, 179, 179], dtype=int64), array([357, 360, 362, ..., 368, 369, 371], dtype=int64)))
# (6568, 15.757155907429963, (array([ 31,  31,  32, ..., 124, 124, 125], dtype=int64), array([538, 548, 531, ..., 541, 548, 548], dtype=int64)))
# (4862, 20.338132455779515, (array([ 25,  25,  25, ..., 103, 104, 104], dtype=int64), array([224, 225, 226, ..., 236, 225, 226], dtype=int64)))

# %%
plt.figure(figsize=(12,12))
plt.subplot(1,4,(1))
plt.imshow(image)
plt.title('image')
plt.subplot(1,4,(2))
plt.imshow(binaryImage,cmap="gray")
plt.title('binaryImage')
plt.subplot(1,4,(3))
plt.imshow(labeledImage,cmap="gray")
plt.title('labeledImage')
plt.subplot(1,4,(4))
plt.imshow(groupImage)
plt.title('groupImage');
