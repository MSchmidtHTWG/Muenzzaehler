# %%
import cv2
# from config import config
from skimage import io
import numpy as np
import os
import time
import sys
import coinimg as ci
# import PySimpleGUI as sg
import os
import matplotlib.pyplot as plt

# %%
cd = ci.loadDict()
for c in cd:
    print(c + str(cd.get(c)))
# Out:
# 2Euro(10975, 12222, 85.64328477334793)
# 1Euro(8843, 10389, 85.91605406161926)
# 50Cent(9613, 11108, 90.32739244725414)
# 20Cent(8014, 9491, 91.25184224891352)
# 10Cent(6228, 7327, 90.67603367726664)
# 5Cent(7081, 8454, 103.85915411800882)
# 2Cent(5549, 6824, 103.24520717771982)
# 1Cent(4096, 5252, 103.25955925604481)

# %%
image = io.imread(f'../testimages/test12.png')
regions, binaryImage, labeledImage, hsvImage = ci.regions(image, minRegionSize=500, threshold=25, return_steps=True)
predictions = ci.predict(regions)
print(predictions)
# Out:
# sizecandidates
# {'2Cent', '10Cent'}
# 6775
# 92.75070110701107
# sizecandidates
# {'1Euro', '20Cent'}
# 9145
# 89.4247129579005
# 1 size candidate
# {'5Cent'}
# 7766
# 104.07906258047902
# sizecandidates
# {'1Euro', '20Cent'}
# 8861
# 93.27096264529963
# 1 size candidate
# {'2Euro'}
# 11820
# 87.36615905245347
# 1 size candidate
# {'50Cent'}
# 10845
# 91.55103734439834
# sizecandidates
# {'2Cent', '10Cent'}
# 6660
# 104.22012012012011
# 1 size candidate
# {'1Cent'}
# 4902
# 99.75214198286413
# ['10Cent', '20Cent', '5Cent', '20Cent', '2Euro', '50Cent', '2Cent', '1Cent']

# %%
for region in regions:
    print(region)
# Out:
# (6727, 92.71815073584064)
# (9088, 89.42473591549296)
# (7640, 104.11479057591623)
# (8786, 93.29547006601412)
# (11767, 87.3866745984533)
# (10749, 91.59279933017025)
# (6568, 104.45828258221681)
# (4862, 99.74784039489921)

# %%
image = io.imread(f'../testimages/test3.png')
regions, binaryImage, labeledImage, hsvImage = ci.regions(image, minRegionSize=500, threshold=30, return_steps=True)
predictions = ci.predict(regions)
print(predictions)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-af1fc584e964> in <module>
#       1 image = io.imread(f'../testimages/test3.png')
# ----> 2 regions, binaryImage, labeledImage, hsvImage = ci.regions(image, minRegionSize=500, threshold=30, return_steps=True)
#       3 predictions = ci.predict(regions)
#       4 print(predictions)
#
# c:\Muenzzaehler\src\coinimg.py in regions(image, minRegionSize, threshold, return_steps)
#     121     binaryImage = rgbToBinary(image, threshold)
#     122     # binaryImage = highContrastToBinary(image)
# --> 123     labeledImage = discreteContrast(sequentialLabeling(binaryImage))
#     124     hsvImage = cv2.cvtColor(image, cv2.COLOR_BGR2HSV)
#     125     # hsvImage[:,:,1] = 255
#
# c:\Muenzzaehler\src\coinimg.py in sequentialLabeling(binaryImage, n)
#     237         b = collisions.pop()
#     238         for labelsets in r:
# --> 239             if labelsets.issuperset({a}):
#     240                 ra = labelsets
#     241             if labelsets.issuperset({b}):
#
# KeyboardInterrupt:

# %%
print(len(regions))
for region in regions:
    print(region)
# Out:
# 8
# (6727, 92.71815073584064)
# (9088, 89.42473591549296)
# (7640, 104.11479057591623)
# (8786, 93.29547006601412)
# (11767, 87.3866745984533)
# (10749, 91.59279933017025)
# (6568, 104.45828258221681)
# (4862, 99.74784039489921)

# %%
plt.figure(figsize=(12,12))
plt.subplot(1,4,(1))
plt.imshow(image)
plt.title('image')
plt.subplot(1,4,(2))
plt.imshow(binaryImage,cmap="gray")
plt.title('binaryImage')
plt.subplot(1,4,(3))
plt.imshow(labeledImage,cmap="gray")
plt.title('labeledImage')
plt.subplot(1,4,(4))
plt.imshow(hsvImage[:,:,0])
plt.title('hsvImage');
