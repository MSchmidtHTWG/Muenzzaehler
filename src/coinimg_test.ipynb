# %%
import cv2
# from config import config
from skimage import io
import numpy as np
import os
import time
import sys
import coinimg as ci
# import PySimpleGUI as sg
import os
import matplotlib.pyplot as plt

# %%
# image = io.imread(f'../crapPics/test1.png')
image = io.imread(f'../crapPics/14%V18%C/1Euro42.png')
regions, binaryImage, labeledImage, hsvImage = ci.regions(image, minRegionSize=500, threshold=10, return_steps=True)

# %%
print(len(regions))
for region in regions:
    print(region)
# Out:
# 9
# (2813, 98.82047635975826)
# (3991, 83.50137810072664)
# (4989, 59.72719983964723)
# (3699, 98.07272235739389)
# (3485, 110.94863701578193)
# (3655, 97.14911080711354)
# (4921, 80.63015647226173)
# (2010, 0.0)
# (19482, 0.0)

# %%
plt.figure(figsize=(12,12))
plt.subplot(1,4,(1))
plt.imshow(image)
plt.title('image')
plt.subplot(1,4,(2))
plt.imshow(binaryImage,cmap="gray")
plt.title('binaryImage')
plt.subplot(1,4,(3))
plt.imshow(labeledImage,cmap="gray")
plt.title('labeledImage')
plt.subplot(1,4,(4))
plt.imshow(hsvImage,cmap="gray")
plt.title('hsvImage');
